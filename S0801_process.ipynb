# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd
from ld_script import *
pd.set_option('display.max_colwidth', None)

# %%
S0801d = pd.read_csv(os.path.join("data/subject_tables/unzipped_files/ACSST5Y2019.S0801_2021-01-12T120320/ACSST5Y2019.S0801_data_with_overlays_2021-01-07T155553.csv"), low_memory=False)
S0801m = pd.read_csv(os.path.join("data/subject_tables/unzipped_files/ACSST5Y2019.S0801_2021-01-12T120320/ACSST5Y2019.S0801_metadata_2021-01-07T155553.csv"))

# %%
print(f'Shape of data table proper is {S0801d.shape} \n'
    + f'Shape of metadata table is {S0801m.shape}')
# Out:
# Shape of data table proper is (5266, 344)
# Shape of metadata table is (343, 2)

# %%
S0801d.head(2)
# Out:
#                  GEO_ID                                       NAME  \
# 0                    id                       Geographic Area Name
# 1  1400000US48001950100  Census Tract 9501, Anderson County, Texas
#
#                                S0801_C01_001E  \
# 0  Estimate!!Total!!Workers 16 years and over
# 1                                        1785
#
#                                       S0801_C01_001M  \
# 0  Margin of Error!!Total!!Workers 16 years and over
# 1                                                293
#
#                                                                                     S0801_C01_002E  \
# 0  Estimate!!Total!!Workers 16 years and over!!MEANS OF TRANSPORTATION TO WORK!!Car, truck, or van
# 1                                                                                             92.3
#
#                                                                                            S0801_C01_002M  \
# ...

# %%
S0801m.head(2)
# Out:
#            GEO_ID                                          id
# 0            NAME                        Geographic Area Name
# 1  S0801_C01_001E  Estimate!!Total!!Workers 16 years and over

# %%
# Custom function defined in ld_scripts.py in project folder to break apart GEO_ID column appropriately
S0801d = parse_geo_id(S0801d)

# %%
S0801d, S0801m = drop_and_normalize(S0801d, S0801m)

# %%
index_locations = [3, *(list(range(23,58,2))), *(list(range(69,99,2)))]
index_locations = [x-3 for x in index_locations]
